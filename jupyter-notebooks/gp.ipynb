# %%
import numpy as np
import matplotlib.pyplot as plt

fitness_values = [346.0, 346.0, 346.0, 346.0, 344.0, 343.0, 344.0, 342.0, 341.0, 335.0, 328.0, 331.0, 331.0, 328.0, 328.0, 328.0, 328.0, 328.0, 328.0, 328.0, 328.0, 328.0, 324.0, 328.0, 328.0,
                  324.0, 328.0, 324.0, 328.0, 324.0, 324.0, 324.0, 328.0, 328.0, 324.0, 324.0, 328.0, 328.0, 324.0, 328.0, 328.0, 324.0, 328.0, 317.0, 317.0, 298.0, 202.0, 140.0, 170.0, 183.0,
                  216.0, 140.0, 124.0, 79.0, 124.0, 136.0, 136.0, 136.0, 180.0, 136.0, 40.0, 30.0, 0.0]
x = np.arange(len(fitness_values))
y = np.array(fitness_values)

plt.title("Fitness graph")
plt.xlabel("Generation")
plt.ylabel("Fitness")
plt.plot(x, y, color ="red")
plt.locator_params(axis='x', nbins=20)
plt.show()
